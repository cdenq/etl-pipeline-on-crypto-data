# %% [markdown]
# Importing Dependencies

# %%
import pandas as pd
import matplotlib as plt
import json
import datetime as dt
import requests
import numpy as np

# %%
import os

#os.getcwd()

# %% [markdown]
# Importing CSV + Creating Variable Filepath

# %%
#creating a variable from csv file path
eth_df = pd.read_csv('../../Resources/ETH-USD.csv')

#checking dataframe
eth_df.head()
# Out:
#          Date        Open         High         Low       Close   Adj Close  \
# 0  2018-01-01  755.757019   782.530029  742.004028  772.640991  772.640991
# 1  2018-01-02  772.346008   914.830017  772.346008  884.443970  884.443970
# 2  2018-01-03  886.000000   974.471008  868.450989  962.719971  962.719971
# 3  2018-01-04  961.713013  1045.079956  946.085999  980.921997  980.921997
# 4  2018-01-05  975.750000  1075.390015  956.325012  997.719971  997.719971
#
#          Volume
# 0  2.595760e+09
# 1  5.783350e+09
# 2  5.093160e+09
# 3  6.502860e+09
# 4  6.683150e+09

# %% [markdown]
# Data Cleaning

# %%
#checking data types 
eth_df.dtypes

print(type(eth_df['Date'][0]))
# Out:
# <class 'str'>

# %%
eth_df['Date']= pd.to_datetime(eth_df['Date'])

#return datetime.date objects without timezone info
eth_df['Date'] = eth_df['Date'].dt.date

eth_df['Date'] = pd.to_datetime(eth_df['Date'])
type(eth_df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#set the index to the Date
eth_df.set_index('Date', inplace = True)

# %%
eth_df.head()
# Out:
#                   Open         High         Low       Close   Adj Close  \
# Date
# 2018-01-01  755.757019   782.530029  742.004028  772.640991  772.640991
# 2018-01-02  772.346008   914.830017  772.346008  884.443970  884.443970
# 2018-01-03  886.000000   974.471008  868.450989  962.719971  962.719971
# 2018-01-04  961.713013  1045.079956  946.085999  980.921997  980.921997
# 2018-01-05  975.750000  1075.390015  956.325012  997.719971  997.719971
#
#                   Volume
# Date
# 2018-01-01  2.595760e+09
# 2018-01-02  5.783350e+09
# 2018-01-03  5.093160e+09
# 2018-01-04  6.502860e+09
# 2018-01-05  6.683150e+09

# %%
# #filtering for the years 2018 - 2021
eth_year_df =eth_df.loc[(eth_df.index.year >= 2018) & (eth_df.index.year <= 2021)]

eth_year_df.head()
# Out:
#                   Open         High         Low       Close   Adj Close  \
# Date
# 2018-01-01  755.757019   782.530029  742.004028  772.640991  772.640991
# 2018-01-02  772.346008   914.830017  772.346008  884.443970  884.443970
# 2018-01-03  886.000000   974.471008  868.450989  962.719971  962.719971
# 2018-01-04  961.713013  1045.079956  946.085999  980.921997  980.921997
# 2018-01-05  975.750000  1075.390015  956.325012  997.719971  997.719971
#
#                   Volume
# Date
# 2018-01-01  2.595760e+09
# 2018-01-02  5.783350e+09
# 2018-01-03  5.093160e+09
# 2018-01-04  6.502860e+09
# 2018-01-05  6.683150e+09

# %%
group_eth_df = eth_year_df.groupby([eth_year_df.index.year, eth_year_df.index.month])

group_eth_df.count()
# Out:
#            Open  High  Low  Close  Adj Close  Volume
# Date Date
# 2018 1       31    31   31     31         31      31
#      2       28    28   28     28         28      28
#      3       31    31   31     31         31      31
#      4       30    30   30     30         30      30
#      5       31    31   31     31         31      31
#      6       30    30   30     30         30      30
#      7       31    31   31     31         31      31
#      8       31    31   31     31         31      31
#      9       30    30   30     30         30      30
#      10      31    31   31     31         31      31
#      11      30    30   30     30         30      30
#      12      31    31   31     31         31      31
# 2019 1       31    31   31     31         31      31
#      2       28    28   28     28         28      28
#      3       31    31   31     31         31      31
#      4       30    30   30     30         30      30
# ...

# %%
# #preparing to convert str to int

# eth_df['Date'] = eth_df['Date'].str.replace(r'-', '').astype(int)
# print(eth_df['Date'])

# %%
clean_eth = []

# %%
clean_eth.append(round(group_eth_df['High'].max(),3))
clean_eth.append(round(group_eth_df['Low'].min(),3))
clean_eth.append(round(group_eth_df['Open'].mean(),3))
clean_eth.append(round(group_eth_df['Close'].mean(),3))
clean_eth.append(round(group_eth_df['High'].max() * group_eth_df['Volume'].max(), 3))

# %%
#Turn it into a Dataframe

clean_eth = pd.DataFrame(clean_eth)
clean_eth = clean_eth.transpose()

# %%
#Naming the newly created columns
clean_eth.rename(columns={'Unnamed 0': 'Marketcap'}, inplace = True)

# %%
clean_eth.index = clean_eth.index.map('{0[0]}0{0[1]}'.format)
clean_eth.index = clean_eth.index.astype(int)

# %%
clean_eth['Symbol'] = 'ETH'
clean_eth['Name'] = 'Ethereum'
clean_eth.reset_index(inplace = True)
clean_eth.rename(columns={'index': 'Date'}, inplace = True)

clean_eth.to_csv('cleaned_eth.csv')
